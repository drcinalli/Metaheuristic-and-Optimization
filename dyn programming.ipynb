# %% [markdown]
# Dynamic Programming

# %% [markdown]
# Optimization technique --- gets the EXACT solution, guarantees the optimal solution
# Break problem into smaller subproblems (stages)
# Standard math formulation is usually absent
# 2 types: deterministic or probabilistic

# %% [markdown]
# Bellman`s principale:  whaever the initial state and the initial decisions are, the remaining decicions must be an optimal policy with regard to the state resulting from the first decisions. (tenho o principio de ótimo se de onde estou conseguir chegar numa solução ótima até o fim do problema.)![image.png](attachment:image.png)
